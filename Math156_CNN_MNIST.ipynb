# %% [markdown]
# ## Convolutional Neural Network for MNIST image classficiation

# %%
# # CNN prediction

# X_test /= np.max(X_test)
# print('X_test.shape', X_test.shape)
# out_test = []


# for i in range(X_test.shape[0]):
#     out_test.append((X_test[i,:].reshape(1,28,28)))
                
# y_hat = CNN0.predict(image_list=out_test)

# y_test_label = np.asarray(onehot2list(y_test))
# P_pred = np.asarray([p[1] for p in y_hat])

# compute_accuracy_metrics(Y_test=y_test_label, P_pred=P_pred, use_opt_threshold=False, verbose=True)

# %%
FINAL PROJECT CNN CLASSIFICATION

# %%
import glob
import matplotlib.pyplot as plt
import random
import pandas as pd
import numpy as np
import seaborn as sns
import os 
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix,classification_report
from PIL import Image
import math as math

# %%
dir = '/Users/jakemarshall/Desktop/Math156 /fire_dataset'
dir_im_fire = dir +'/fire_images/'
dir_im_nonfire = dir +'/non_fire_images/'

lst_fire_img = glob.glob(dir_im_fire + '*.png')
lst_non_fire_img = glob.glob(dir_im_nonfire + '*.png')

# %%
#lst_non_fire_img
print ('found ', len(lst_fire_img), ' fire images and ', len(lst_non_fire_img), 'non fire images')
# Out:
# found  755  fire images and  244 non fire images

# %%
# resize images and create a new repository

# new image dimension
# lower this number if you want to run fatster

img_size_x=100 
img_size_y=100 

sub_fol = 'resized'+'_'+str(img_size_x)+'x'+str(img_size_y)
path_fire_resize = dir_im_fire + sub_fol 
path_non_fire_resize = dir_im_nonfire + sub_fol 


# check if dir exists if no create a new directory under each folder ( fire and non fire) to store the resized images. 
# attention: if dir exists and there are files, it will not delete old stuff. You have to do it manually. 

check_folder = os.path.isdir(path_fire_resize)

# If folder doesn't exist, then create it.
if not check_folder:
    os.makedirs(path_fire_resize)
    print("created folder : ", path_fire_resize)

else:
    print(path_fire_resize, "folder already exists.")


for i in range(len(lst_fire_img)):
    
    img = Image.open(lst_fire_img[i])
    new_img= img.resize((img_size_x,img_size_y))
    #new_name = str(img_size_x)+'x'+str(img_size_y)+lst_fire_img[i]
    new_s = '_'+str(img_size_x)+'x'+str(img_size_y)+'.png'
    new_name = lst_fire_img[i].replace('.png', new_s)
    
    new_img.save(new_name.replace('fire_images','fire_images/'+sub_fol+'/'))
    print ('creating ', new_name)


#nonfire 
    check_folder = os.path.isdir(path_non_fire_resize)

# If folder doesn't exist, then create it.
if not check_folder:
    os.makedirs(path_non_fire_resize)
    print("created folder : ", path_non_fire_resize)

else:
    print(path_non_fire_resize, "folder already exists.")


for i in range(len(lst_non_fire_img)):
    
    img = Image.open(lst_non_fire_img[i])
    new_img= img.resize((img_size_x,img_size_y))
    #new_name = str(img_size_x)+'x'+str(img_size_y)+lst_fire_img[i]
    new_s = '_'+str(img_size_x)+'x'+str(img_size_y)+'.png'
    new_name = lst_non_fire_img[i].replace('.png', new_s)
    
    new_img.save(new_name.replace('non_fire_images','non_fire_images/'+sub_fol+'/'))
    print ('creating ', new_name)
# Out:
# /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/resized_100x100 folder already exists.
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.753_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.12_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.747_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.592_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.586_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.579_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.237_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.551_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.545_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.223_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.380_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.394_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.419_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.343_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.425_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.431_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.357_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.182_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.196_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.169_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.627_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.141_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.155_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.633_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.154_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.632_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.626_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.140_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.168_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.197_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.183_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.430_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.356_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.342_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.424_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.418_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.395_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.381_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.544_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.222_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.236_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.550_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.578_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.587_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.593_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.746_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.13_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.752_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.39_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.11_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.744_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.750_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.585_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.591_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.208_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.220_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.546_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.552_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.234_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.397_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.383_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.368_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.354_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.432_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.426_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.340_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.195_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.181_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.618_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.630_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.156_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.142_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.624_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.143_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.625_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.631_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.157_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.619_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.180_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.194_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.427_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.341_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.355_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.433_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.369_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.382_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.396_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.553_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.235_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.221_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.547_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.209_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.590_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.584_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.751_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.745_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.10_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.38_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.741_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.14_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.755_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.28_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.580_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.594_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.543_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.225_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.231_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.557_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.219_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.392_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.386_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.437_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.351_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.345_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.423_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.379_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.190_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.184_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.153_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.635_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.621_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.147_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.609_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.608_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.620_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.146_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.152_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.634_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.185_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.191_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.378_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.344_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.422_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.436_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.350_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.387_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.393_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.218_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.230_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.556_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.542_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.224_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.595_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.581_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.29_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.754_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.15_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.740_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.742_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.17_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.597_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.583_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.554_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.232_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.226_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.540_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.568_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.385_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.391_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.420_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.346_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.352_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.434_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.408_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.187_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.193_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.144_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.622_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.636_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.150_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.178_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.179_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.637_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.151_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.145_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.623_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.192_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.186_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.409_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.353_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.435_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.421_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.347_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.390_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.384_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.569_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.227_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.541_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.555_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.233_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.582_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.596_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.16_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.743_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.59_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.718_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.65_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.730_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.71_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.724_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.297_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.283_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.268_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.532_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.254_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.240_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.526_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.485_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.491_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.308_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.446_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.320_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.334_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.452_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.687_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.693_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.678_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.122_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.644_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.650_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.136_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.651_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.137_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.123_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.645_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.679_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.692_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.686_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.335_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.453_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.447_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.321_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.309_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.490_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.484_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.241_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.527_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.533_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.255_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.269_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.282_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.296_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.725_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.70_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.731_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.64_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.719_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.58_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.99_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.72_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.727_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.66_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.733_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.280_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.294_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.519_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.525_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.243_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.257_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.531_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.492_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.486_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.479_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.451_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.337_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.8_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.323_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.445_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.690_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.684_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.109_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.135_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.653_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.647_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.121_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.646_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.120_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.134_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.652_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.108_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.685_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.691_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.322_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.444_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.450_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.9_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.336_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.478_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.487_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.493_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.256_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.530_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.524_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.242_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.518_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.295_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.281_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.732_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.67_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.726_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.73_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.98_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.88_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.722_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.77_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.736_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.63_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.285_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.291_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.246_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.520_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.534_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.252_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.508_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.497_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.483_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.332_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.454_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.440_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.326_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.468_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.695_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.681_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.656_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.130_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.124_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.642_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.118_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.119_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.125_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.643_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.657_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.131_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.680_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.694_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.469_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.441_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.327_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.333_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.455_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.482_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.496_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.509_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.535_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.253_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.247_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.521_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.290_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.284_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.62_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.737_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.76_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.723_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.89_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.735_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.60_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.721_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.74_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.709_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.48_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.292_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.286_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.251_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.537_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.523_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.245_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.279_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.480_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.494_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.325_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.443_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.457_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.331_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.319_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.682_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.696_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.641_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.127_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.133_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.655_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.669_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.668_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.132_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.654_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.640_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.126_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.697_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.683_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.318_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.456_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.330_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.324_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.442_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.495_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.481_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.278_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.522_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.244_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.250_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.536_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.287_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.293_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.49_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.708_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.75_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.720_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.61_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.734_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.87_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.93_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.78_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.739_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.44_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.711_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.50_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.705_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.249_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.513_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.275_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.261_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.507_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.498_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.2_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.329_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.467_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.301_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.315_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.473_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.659_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.103_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.665_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.671_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.117_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.670_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.116_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.102_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.664_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.658_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.314_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.472_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.466_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.300_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.328_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.3_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.499_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.260_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.506_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.512_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.274_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.248_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.704_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.51_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.710_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.45_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.738_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.79_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.92_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.86_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.90_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.84_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.53_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.706_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.47_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.712_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.289_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.538_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.504_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.262_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.276_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.510_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.1_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.458_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.470_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.316_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.302_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.464_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.699_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.128_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.114_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.672_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.666_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.100_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.667_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.101_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.115_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.673_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.129_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.698_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.303_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.465_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.471_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.317_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.459_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.277_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.511_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.505_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.263_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.539_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.288_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.713_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.46_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.707_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.52_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.85_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.91_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.95_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.81_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.703_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.56_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.717_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.42_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.298_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.267_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.501_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/fire.515_100x100.png
# ...
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.168_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.183_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.197_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.236_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.33_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.27_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.7_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.222_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.223_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.6_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.26_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.32_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.237_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.196_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.182_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.169_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.155_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.141_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.179_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.145_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.151_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.186_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.192_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.233_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.36_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.22_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.2_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.227_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.226_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.3_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.23_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.37_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.232_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.193_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.187_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.150_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.144_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.178_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.152_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.146_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.191_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.185_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.218_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.21_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.1_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.224_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.230_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.35_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.34_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.231_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.225_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.20_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.219_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.184_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.190_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.147_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.153_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.176_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.162_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.189_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.200_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.11_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.214_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.39_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.228_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.229_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.38_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.215_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.10_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.201_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.188_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.163_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.177_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.161_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.175_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.149_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.12_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.217_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.203_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.202_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.216_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.13_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.148_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.174_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.160_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.158_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.164_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.170_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.17_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.212_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.206_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.207_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.213_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.16_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.171_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.165_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.159_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.173_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.167_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.198_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.239_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.28_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.8_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.205_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.14_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.211_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.210_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.15_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.204_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.9_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.29_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.238_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.199_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.166_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.172_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.115_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.101_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.129_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.66_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.72_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.99_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.98_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.73_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.67_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.128_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.100_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.114_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.102_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.116_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.71_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.65_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.59_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.58_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.64_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.70_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.117_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.103_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.107_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.113_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.48_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.74_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.60_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.61_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.75_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.49_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.112_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.106_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.138_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.110_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.104_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.63_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.77_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.88_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.89_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.76_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.62_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.105_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.111_100x100.png
# creating  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/non_fire.139_100x100.png

# %%
#print(path_fire_resize + '/*.png')
#print(path_fire_resize )
lst_fire_img = glob.glob(path_fire_resize + '/*.png')
lst_non_fire_img = glob.glob(path_non_fire_resize + '/*.png')

#lst_non_fire_img
print ('FOUND \n ', len(lst_fire_img), ' fire images in', path_fire_resize ,' and \n ', len(lst_non_fire_img), 'non fire images in ', path_non_fire_resize)
# Out:
# FOUND
#   755  fire images in /Users/jakemarshall/Desktop/Math156 /fire_dataset/fire_images/resized_100x100  and
#   244 non fire images in  /Users/jakemarshall/Desktop/Math156 /fire_dataset/non_fire_images/resized_100x100

# %%
# plot a few random images 


lst_images_random = random.sample(lst_fire_img,10) + random.sample(lst_non_fire_img,10)
random.shuffle(lst_images_random)

plt.figure(figsize = (20,20))

#print(lst_images_random)

for i in range(len(lst_images_random)):
    
    plt.subplot(4,5,i+1)


    if "non_fire" in lst_images_random[i]:
        #img = cv2.imread(lst_images_random[i])
        img = Image.open(lst_images_random[i])
        #img = cv2.cvtColor(img,cv2.COLOR_RGB2BGR)
        new_img= img.resize((img_size_x,img_size_y))
        plt.imshow(new_img,cmap = 'gray')
        plt.title('Image without fire')
        #print('image name',img)

    else:
        #img = cv2.imread(lst_images_random[i])
        #img = cv2.cvtColor(img,cv2.COLOR_RGB2BGR)
        #plt.imshow(lst_images_random[i].reshape(28,28))
        img = Image.open(lst_images_random[i])
        plt.imshow(img,cmap = 'gray')
        plt.title("Image with fire")



plt.show()

# %%
# create a datafram with all images 

lst_fire = []
for x in lst_fire_img:
  lst_fire.append([x,1])
lst_nn_fire = []
for x in lst_non_fire_img:
  lst_nn_fire.append([x,0])
lst_complete = lst_fire + lst_nn_fire
random.shuffle(lst_complete)

# %%
df = pd.DataFrame(lst_complete, columns = ['files','target'])
df.head(10)
# Out:
#                                                files  target
# 0  /Users/jakemarshall/Desktop/Math156 /fire_data...       1
# 1  /Users/jakemarshall/Desktop/Math156 /fire_data...       1
# 2  /Users/jakemarshall/Desktop/Math156 /fire_data...       0
# 3  /Users/jakemarshall/Desktop/Math156 /fire_data...       0
# 4  /Users/jakemarshall/Desktop/Math156 /fire_data...       0
# 5  /Users/jakemarshall/Desktop/Math156 /fire_data...       1
# 6  /Users/jakemarshall/Desktop/Math156 /fire_data...       1
# 7  /Users/jakemarshall/Desktop/Math156 /fire_data...       1
# 8  /Users/jakemarshall/Desktop/Math156 /fire_data...       1
# 9  /Users/jakemarshall/Desktop/Math156 /fire_data...       0

# %%
Y = []
X= []
for i in range(len(lst_complete)):
#for i in range(10):
        if (i%50) == 0: print('appending image...', i)
        img = Image.open(lst_complete[i][0])
        pix = np.array(img.getdata())
        #print('shape of pic ', pix.shape)
        #print('pix dhape)', (pix.flatten()).shape)
        #pix = np.array(img.getdata()).flatten()
        if pix.shape == (10000, 3):
            pix1 = pix.ravel()
            X.append(pix1)
            Y.append(lst_complete[i][1])
        

print('shape of pic ', pix1.shape)

#X = np.transpose(X)
#X = np.transpose(X)
X = np.array(X)
Y = np.array(Y)
print('shape of x ', X.shape)

#transform the images into an array X and Y so they can be used as input to the ML algos

print(len(X))
#print(X[7,:])
#print('X.shape', X.shape)
print('y.shape', Y.shape)


# plot random image from the original data set 
img = Image.open(lst_complete[7][0])
pix = np.array(img.getdata())
flat_list = pix.ravel()
pix = np.array(flat_list).reshape(img_size_x,img_size_y,3)
plt.imshow(pix,cmap = 'gray')
plt.title("Image from orig data set")
plt.show()


# plot random image from X array 
myfile = (X[7])
myi = myfile.reshape(img_size_x, img_size_y, 3)
# print randome image 
plt.imshow(myi,cmap = 'gray')
plt.title("Image from X data set")


'''
Each row of X is a vectorization of an image of img_size_x x img_size_y x 3 pixels.  
The corresponding row of y holds the true class label from {0,1}
'''
# Out:
# appending image... 0
# appending image... 50
# appending image... 100
# appending image... 150
# appending image... 200
# appending image... 250
# appending image... 300
# appending image... 350
# appending image... 400
# appending image... 450
# appending image... 500
# appending image... 550
# appending image... 600
# appending image... 650
# appending image... 700
# appending image... 750
# appending image... 800
# appending image... 850
# appending image... 900
# appending image... 950
# shape of pic  (30000,)
# shape of x  (990, 30000)
# 990
# y.shape (990,)
# '\nEach row of X is a vectorization of an image of img_size_x x img_size_y x 3 pixels.  \nThe corresponding row of y holds the true class label from {0,1}\n'

# %%
#touple X with Y

#make y one-hot-encoded
Y01 = list2onehot(Y, [0,1])

#normalize X
X = X/255

print('Y ', Y01.shape)
print('X ', X.shape)

X_train = []
X_test = []
y_test = [] # list of one-hot encodings (indicator vectors) of each label  
y_train = [] # list of one-hot encodings (indicator vectors) of each label 

count_bad = []
for i in range(len(Y01)):
    
        # for each example i, make it into train set with probabiliy 0.8 and into test set otherwise
        # in each case, ignore X[i] if it isn't the right size (there are 9 images that don't match size)
        U = np.random.rand() # Uniform([0,1]) variable
        if U<0.8:
            X_train.append(X[i])
            y_train.append(Y01[i])
        else:
            X_test.append(X[i])
            y_test.append(Y01[i])

X_train = np.asarray(X_train)
X_test = np.asarray(X_test)
y_train = np.asarray(y_train)
y_test = np.asarray(y_test)

print('ytrain ', y_train.shape)
print('ytest ', y_test.shape)
print('Xtrain ', X_train.shape)
print('Xtest ', X_test.shape)


## set size of set for CNN training -- make sure there are enough non-fire (half and half)
num_F = 25
num_NF = 25
count_NF = 0
count_F  = 0
idx = []
for i in np.arange(len(y_train)):
    
    id = np.random.choice(np.arange(len(y_train)), 1)
    if y_train[id][0][0] == 1 and count_NF <= num_NF:
        idx.append(id)
        count_NF += 1
    elif y_train[id][0][1] == 1 and count_F <= num_F:
        idx.append(id)
        count_F += 1
   
idx = np.asarray(idx)
idx = idx.squeeze()
X_train0 = X_train[idx]
y_train0 = y_train[idx]


#==========================================================================================


# Package training data with 25 fire images, 25 no fire images

out = []
# populate the tuple list with the data
for i in range(len(y_train0)):
    item = list((X_train0[i].reshape(3,100,100), y_train0[i])) 
    out.append(item)

#=================================================================

# package data for predictions
out_train = []
# populate the tuple list with the data
for i in range(X_train.shape[0]):
    item = (X_train[i].reshape(3,100,100))
    out_train.append(item)

    
# ================================================================
# Package test data - 100 fire images, 100 no fire images
num_NF = 100
num_F = 100
count_NF = 0
count_F  = 0
idx_test = []
for i in range(800):
    
    id = np.random.choice(np.arange(len(y_test)), 1)
    if y_test[id][0][0]== 1 and count_NF < num_NF:
        idx_test.append(id)
        count_NF += 1
    elif y_test[id][0][0] == 0 and count_F < num_F:
        idx_test.append(id)
        count_F += 1

idx_test = np.asarray(idx_test)
idx_test = idx_test.squeeze()
X_test0 = X_test[idx_test]
y_test0 = y_test[idx_test]

# test data 
out_test = []
for i in range(X_test0.shape[0]):
    item = (X_test0[i].reshape(3,100,100))
    out_test.append(item)
# Out:
# Y  (990, 2)
# X  (990, 30000)
# ytrain  (799, 2)
# ytest  (191, 2)
# Xtrain  (799, 30000)
# Xtest  (191, 30000)

# %%
# FFNN training
CNN0 = CNN(training_data = out,
           f = 5, # conv filter dim
           f_pool = 2, # maxpool filter dim
           num_filt1 = 8, # num filters for the first conv layer
           num_filt2 = 8, # num filters for the second conv layer
           conv_stride = 1,
           pool_stride = 2,
           hidden_nodes = 100)
# Out:
# self.img_x_dim 100

# %%
CNN0.train(lr = 0.01,
           beta1 = 0.95,
           beta2 = 0.99,
           minibatch_size = 32,
           num_epochs = 20,
           verbose = True)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# LR:0.01, MiniBatch Size:32
#   5%|▌         | 1/20 [08:10<2:35:25, 490.81s/it]
# epoch 0, error 0.69543
#  30%|███       | 6/20 [47:02<1:50:10, 472.21s/it]
# epoch 5, error 0.69431
#  55%|█████▌    | 11/20 [1:27:31<1:12:52, 485.87s/it]
# epoch 10, error 0.69315
#  80%|████████  | 16/20 [2:04:40<29:56, 449.11s/it]
# epoch 15, error 0.69367
# 100%|██████████| 20/20 [2:38:03<00:00, 474.17s/it]
# [0.6931471805599462,
#  0.6954330975177394,
#  0.6931622895776515,
#  0.6936643778380452,
#  0.6930311833464852,
#  0.6947908602533481,
#  0.693147252595182,
#  0.6931471970873406,
#  0.6931456514123105,
#  0.6937360269189972,
#  0.6932513567397123,
#  0.6943056052628879,
#  0.693089107045644,
#  0.6938416949423893,
#  0.693034415362226,
#  0.6963252749707756,
#  0.6931136145344898,
#  0.693726808237343,
#  0.6931473032254727,
#  0.6931471861648095,
#  0.6931471810077711,
#  0.6931471806821731,
#  0.6931474967947582,
#  0.6936665179925503,
#  0.6931418291259748,
#  0.6936772921665897,
#  0.6931478060510251,
#  0.6936688248527321,
#  0.693139509961505,
#  0.6936964508430352,
#  0.6931492127251608,
#  0.693667521206905,
#  0.6931384728179335,
#  0.6936860067789758,
#  0.6931454593573314,
#  0.6936720574275037,
#  0.6931346210018612,
#  0.6948067851038321,
#  0.6931537591317921,
#  0.6936489942798991]

# %%
# FFNN prediction
print()
y_hat_train = np.asarray(CNN0.predict(out_train))
y_hat_test = np.asarray(CNN0.predict(out_test))


# confusion matrix of predicting
results_train = multiclass_accuracy_metrics(Y_test=y_train, P_pred=y_hat_train)
results_test = multiclass_accuracy_metrics(Y_test=y_test0, P_pred=y_hat_test)
# Out:
#   0%|          | 0/799 [00:00<?, ?it/s]
# 100%|██████████| 799/799 [35:43<00:00,  2.68s/it]
# 100%|██████████| 202/202 [21:34<00:00,  6.41s/it]

# %%
results_train = multiclass_accuracy_metrics(Y_test=y_train, P_pred=y_hat_train)
results_test = multiclass_accuracy_metrics(Y_test=y_test0, P_pred=y_hat_test)
# Out:
# !!! confusion_mx [[  0 193]
#  [  0 606]]
# !!! Accuracy 0.7584480600750939
# !!! confusion_mx [[  0 101]
#  [  0 101]]
# !!! Accuracy 0.5

# %%
'''
Description: Convolutional Neural Network implemented using numpy
Author: Alejandro Escontrela
Version: V.1.
Date: June 12th, 2018
Modification by Hanbaek Lyu (5/11/2021)
'''

import numpy as np
import pickle
from tqdm import tqdm, trange
from sklearn import metrics
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

#####################################################
############### Building The Network ################
#####################################################

class CNN(object):
    """
    Input data type: training_data = [pattern1, pattern2, ..., pattern n]
    pattern i = [np.array (input), np.array (output in one-hot encoding)]
    Input --> Conv1 + ReLU + MaxPool --> Conv2 + ReLU + MaxPool --> Dense1 + ReLU --> Dense2 + Softmax --> predictive PMF
    """
    def __init__(self,
                 training_data,
                 f = 5, # conv filter dim
                 f_pool = 2, # maxpool filter dim
                 num_filt1 = 8, # num filters for the first conv layer
                 num_filt2 = 8, # num filters for the second conv layer
                 conv_stride = 1,
                 pool_stride = 2,
                 hidden_nodes = 128):

        self.training_data = training_data
        self.img_depth, self.img_x_dim, self.img_y_dim = training_data[0][0].shape
        print('self.img_x_dim', self.img_x_dim)
        self.num_classes = len(training_data[0][1])
        self.num_filt1 = num_filt1
        self.num_filt2 = num_filt2
        self.f = f # conv filter dim
        self.f_pool = f_pool # maxpool filter dim
        self.num_filt1 = num_filt1 # num filters for the first conv layer
        self.num_filt2 = num_filt2 # num filters for the second conv layer
        self.conv_stride = conv_stride
        self.pool_stride = pool_stride
        self.hidden_nodes = hidden_nodes


        ## Initializing all the parameters
        h_dim, w_dim = self.compute_conv_dim()
        f1 = self.initializeFilter((num_filt1 ,self.img_depth,f,f))
        f2 = self.initializeFilter((num_filt2 ,num_filt1,f,f)) # Initialize a set of filters for each channel (maybe unnecessary)
        w3 = self.initializeWeight((hidden_nodes, num_filt2 * h_dim * w_dim))
        w4 = self.initializeWeight((self.num_classes, hidden_nodes))

        # biases
        b1 = np.zeros((f1.shape[0],1))
        b2 = np.zeros((f2.shape[0],1))
        b3 = np.zeros((w3.shape[0],1))
        b4 = np.zeros((w4.shape[0],1))

        self.params = {}
        self.params.update({'f1': f1})
        self.params.update({'f2': f2})
        self.params.update({'w3': w3})
        self.params.update({'w4': w4})
        self.params.update({'b1': b1})
        self.params.update({'b2': b2})
        self.params.update({'b3': b3})
        self.params.update({'b4': b4})

    def compute_conv_dim(self):
        h_dim = self.img_x_dim
        w_dim = self.img_y_dim

        # conv1
        h_dim = int((h_dim - self.f)/self.conv_stride)+1
        w_dim = int((w_dim - self.f)/self.conv_stride)+1

        # maxpool
        h_dim = int((h_dim - self.f_pool)/self.pool_stride)+1
        w_dim = int((w_dim - self.f_pool)/self.pool_stride)+1

        # conv 2
        h_dim = int((h_dim - self.f)/self.conv_stride)+1
        w_dim = int((w_dim - self.f)/self.conv_stride)+1

        # maxpool
        h_dim = int((h_dim - self.f_pool)/self.pool_stride)+1
        w_dim = int((w_dim - self.f_pool)/self.pool_stride)+1
        return h_dim, w_dim

    def initializeFilter(self, size, scale = 1.0):
        stddev = scale/np.sqrt(np.prod(size))
        return np.random.normal(loc = 0, scale = stddev, size = size)

    def initializeWeight(self, size):
        return np.random.standard_normal(size=size) * 0.01

    def conv(self, image, label):

        # ForwardPropragate + BackPropagate + Compute Gradients

        conv_s, pool_f, pool_s = self.conv_stride, self.f_pool, self.pool_stride

        f1 = self.params.get('f1')
        f2 = self.params.get('f2')
        w3 = self.params.get('w3')
        w4 = self.params.get('w4')
        b1 = self.params.get('b1')
        b2 = self.params.get('b2')
        b3 = self.params.get('b3')
        b4 = self.params.get('b4')

        ################################################
        ############## Forward Operation ###############
        ################################################
        conv1 = self.convolution(image, f1, b1, conv_s) # convolution operation
        conv1[conv1<=0] = 0 # pass through ReLU non-linearity
        pooled1 = self.maxpool(conv1, pool_f, pool_s) # maxpooling operation

        conv2 = self.convolution(pooled1, f2, b2, conv_s) # second convolution operation
        conv2[conv2<=0] = 0 # pass through ReLU non-linearity
        pooled2 = self.maxpool(conv2, pool_f, pool_s) # maxpooling operation

        (nf2, dim2, _) = pooled2.shape
        fc = pooled2.reshape((nf2 * dim2 * dim2, 1)) # flatten pooled layer
        # print('fc.shape', fc.shape)

        z = w3.dot(fc) + b3 # first dense layer
        z[z<=0] = 0 # pass through ReLU non-linearity
        # print('z.shape', z.shape)

        out = w4.dot(z) + b4 # second dense layer

        # print('out.shape', out.shape)

        probs = softmax(out) # predict class probabilities with the softmax activation function

        # print('probs.shape', probs.shape)

        ################################################
        #################### Loss ######################
        ################################################

        loss = categoricalCrossEntropy(probs, label) # categorical cross-entropy loss
        # print('loss',loss)

        ################################################
        ############# Backward Operation ###############
        ################################################

        dout = probs - label # derivative of loss w.r.t. final dense layer output

        dw4 = dout.dot(z.T) # loss gradient of final dense layer weights
        db4 = np.sum(dout, axis = 1).reshape(b4.shape) # loss gradient of final dense layer biases

        dz = w4.T.dot(dout) # loss gradient of first dense layer outputs
        dz[z<=0] = 0 # backpropagate through ReLU
        dw3 = dz.dot(fc.T)
        db3 = np.sum(dz, axis = 1).reshape(b3.shape)

        dfc = w3.T.dot(dz) # loss gradients of fully-connected layer (pooling layer)
        dpool2 = dfc.reshape(pooled2.shape) # reshape fully connected into dimensions of pooling layer

        dconv2 = self.maxpoolBackward(dpool2, conv2, pool_f, pool_s) # backprop through the max-pooling layer(only neurons with highest activation in window get updated)
        dconv2[conv2<=0] = 0 # backpropagate through ReLU
        dpool1, df2, db2 = self.convolutionBackward(dconv2, pooled1, f2, conv_s) # backpropagate previous gradient through second convolutional layer.

        dconv1 = self.maxpoolBackward(dpool1, conv1, pool_f, pool_s) # backprop through the max-pooling layer(only neurons with highest activation in window get updated)
        dconv1[conv1<=0] = 0 # backpropagate through ReLU
        dimage, df1, db1 = self.convolutionBackward(dconv1, image, f1, conv_s) # backpropagate previous gradient through first convolutional layer.

        grads = [df1, df2, dw3, dw4, db1, db2, db3, db4]

        return grads, loss



    #####################################################
    ################### Optimization ####################
    #####################################################

    def adamGD(self, minibatch, lr, beta1, beta2, cost):
        '''
        update the parameters through Adam gradient descnet (A fancy version of GD)
        batch = [pattern1, pattern2, .. pattern n']
        pattern i = [np.array (input img), np.array (output)]
        '''
        f1 = self.params.get('f1')
        f2 = self.params.get('f2')
        w3 = self.params.get('w3')
        w4 = self.params.get('w4')
        b1 = self.params.get('b1')
        b2 = self.params.get('b2')
        b3 = self.params.get('b3')
        b4 = self.params.get('b4')

        batch_size = len(minibatch)

        cost_ = 0

        # initialize gradients and momentum,RMS params
        # TODO: Simplify the following initialization
        df1 = np.zeros(f1.shape)
        df2 = np.zeros(f2.shape)
        dw3 = np.zeros(w3.shape)
        dw4 = np.zeros(w4.shape)
        db1 = np.zeros(b1.shape)
        db2 = np.zeros(b2.shape)
        db3 = np.zeros(b3.shape)
        db4 = np.zeros(b4.shape)

        v1 = np.zeros(f1.shape)
        v2 = np.zeros(f2.shape)
        v3 = np.zeros(w3.shape)
        v4 = np.zeros(w4.shape)
        bv1 = np.zeros(b1.shape)
        bv2 = np.zeros(b2.shape)
        bv3 = np.zeros(b3.shape)
        bv4 = np.zeros(b4.shape)

        s1 = np.zeros(f1.shape)
        s2 = np.zeros(f2.shape)
        s3 = np.zeros(w3.shape)
        s4 = np.zeros(w4.shape)
        bs1 = np.zeros(b1.shape)
        bs2 = np.zeros(b2.shape)
        bs3 = np.zeros(b3.shape)
        bs4 = np.zeros(b4.shape)

        for i in np.arange(len(minibatch)):
            x = minibatch[i][0].reshape(self.img_depth, self.img_x_dim, self.img_y_dim)
            y = minibatch[i][1].reshape(-1,1)

            # Collect Gradients for training example
            # stride for conv = 1
            # stride for maxpool = 2
            # maxpool filter dim = 2
            grads, loss = self.conv(image=x, label=y)
            [df1_, df2_, dw3_, dw4_, db1_, db2_, db3_, db4_] = grads

            df1+=df1_
            db1+=db1_
            df2+=df2_
            db2+=db2_
            dw3+=dw3_
            db3+=db3_
            dw4+=dw4_
            db4+=db4_

            cost_+= loss

        # Parameter Update
        v1 = beta1*v1 + (1-beta1)*df1/batch_size # momentum update
        s1 = beta2*s1 + (1-beta2)*(df1/batch_size)**2 # RMSProp update
        f1 -= lr * v1/np.sqrt(s1+1e-7) # combine momentum and RMSProp to perform update with Adam

        bv1 = beta1*bv1 + (1-beta1)*db1/batch_size
        bs1 = beta2*bs1 + (1-beta2)*(db1/batch_size)**2
        b1 -= lr * bv1/np.sqrt(bs1+1e-7)

        v2 = beta1*v2 + (1-beta1)*df2/batch_size
        s2 = beta2*s2 + (1-beta2)*(df2/batch_size)**2
        f2 -= lr * v2/np.sqrt(s2+1e-7)

        bv2 = beta1*bv2 + (1-beta1) * db2/batch_size
        bs2 = beta2*bs2 + (1-beta2)*(db2/batch_size)**2
        b2 -= lr * bv2/np.sqrt(bs2+1e-7)

        v3 = beta1*v3 + (1-beta1) * dw3/batch_size
        s3 = beta2*s3 + (1-beta2)*(dw3/batch_size)**2
        w3 -= lr * v3/np.sqrt(s3+1e-7)

        bv3 = beta1*bv3 + (1-beta1) * db3/batch_size
        bs3 = beta2*bs3 + (1-beta2)*(db3/batch_size)**2
        b3 -= lr * bv3/np.sqrt(bs3+1e-7)

        v4 = beta1*v4 + (1-beta1) * dw4/batch_size
        s4 = beta2*s4 + (1-beta2)*(dw4/batch_size)**2
        w4 -= lr * v4 / np.sqrt(s4+1e-7)

        bv4 = beta1*bv4 + (1-beta1)*db4/batch_size
        bs4 = beta2*bs4 + (1-beta2)*(db4/batch_size)**2
        b4 -= lr * bv4 / np.sqrt(bs4+1e-7)


        cost_ = cost_/batch_size
        cost.append(cost_)

        params = {}
        params.update({'f1': f1})
        params.update({'f2': f2})
        params.update({'w3': w3})
        params.update({'w4': w4})
        params.update({'b1': b1})
        params.update({'b2': b2})
        params.update({'b3': b3})
        params.update({'b4': b4})

        return params, cost

    #####################################################
    ##################### Training ######################
    #####################################################

    def train(self,
              lr = 0.01,
              beta1 = 0.95,
              beta2 = 0.99,
              minibatch_size = 32,
              num_epochs = 2,
              verbose = False,
              save_path = 'params.pkl'):


        # np.random.shuffle(X)

        cost = []

        print("LR:"+str(lr)+", MiniBatch Size:"+str(minibatch_size))

        for epoch in trange(num_epochs):

            # sample a minibatch:
            #X = []
            #Y = []
            # idx = np.random.choice(np.arange(len(self.training_data)), minibatch_size)
            #pattern = self.training_data[idx[i]]
            #X.append(pattern[0])
            #Y.append(pattern[1])

            np.random.shuffle(self.training_data)
            batches = [self.training_data[k:k + minibatch_size] for k in range(0, len(self.training_data), minibatch_size)]
            for i in np.arange(len(batches)):
                params, cost = self.adamGD(minibatch=batches[i],
                                           lr=lr, # learning rate
                                           beta1=beta1,
                                           beta2=beta2,
                                           cost=cost)
                # t.set_description("Cost: %.2f" % (cost[-1]))
            # update parameters

            self.params = params
            if (epoch % 5 == 0) and verbose:
                print('epoch %i, error %-.5f' % (epoch, cost[-1]))

            #if cost[-1] < 0.01:
            #    break

        to_save = [params, cost]


        with open(save_path, 'wb') as file:
            pickle.dump(to_save, file)

        return cost



    #####################################################
    ################ Forward Operations #################
    #####################################################


    def convolution(self, image, filt, bias, s=1):
        '''
        Confolves `filt` over `image` using stride `s`
        '''
        (n_f, n_c_f, f, _) = filt.shape # filter dimensions (# filters, filter depth, filter dim, filder dim)
        # print('filt.shape', filt.shape)
        n_c, in_dim, _ = image.shape # image dimensions
        # print('image.shape', image.shape)

        out_dim = int((in_dim - f)/s)+1 # calculate output dimensions

        assert n_c == n_c_f, "Filter depth must match depth of input image"

        out = np.zeros((n_f,out_dim,out_dim))

        # convolve the filter over every part of the image, adding the bias at each step.
        for curr_f in range(n_f):
            curr_y = out_y = 0
            while curr_y + f <= in_dim:
                curr_x = out_x = 0
                while curr_x + f <= in_dim:
                    out[curr_f, out_y, out_x] = np.sum(filt[curr_f] * image[:,curr_y:curr_y+f, curr_x:curr_x+f]) + bias[curr_f]
                    curr_x += s
                    out_x += 1
                curr_y += s
                out_y += 1

        return out

    def maxpool(self, image, f=2, s=2):
        '''
        Downsample `image` using kernel size `f` and stride `s`
        '''
        n_c, h_prev, w_prev = image.shape

        h = int((h_prev - f)/s)+1
        w = int((w_prev - f)/s)+1

        downsampled = np.zeros((n_c, h, w))
        for i in range(n_c):
            # slide maxpool window over each part of the image and assign the max value at each step to the output
            curr_y = out_y = 0
            while curr_y + f <= h_prev:
                curr_x = out_x = 0
                while curr_x + f <= w_prev:
                    downsampled[i, out_y, out_x] = np.max(image[i, curr_y:curr_y+f, curr_x:curr_x+f])
                    curr_x += s
                    out_x += 1
                curr_y += s
                out_y += 1
        return downsampled




    #####################################################
    ############### Backward Operations #################
    #####################################################

    def convolutionBackward(self, dconv_prev, conv_in, filt, s):
        '''
        Backpropagation through a convolutional layer.
        '''
        (n_f, n_c, f, _) = filt.shape
        (_, orig_dim, _) = conv_in.shape
        ## initialize derivatives
        dout = np.zeros(conv_in.shape)
        dfilt = np.zeros(filt.shape)
        dbias = np.zeros((n_f,1))
        for curr_f in range(n_f):
            # loop through all filters
            curr_y = out_y = 0
            while curr_y + f <= orig_dim:
                curr_x = out_x = 0
                while curr_x + f <= orig_dim:
                    # loss gradient of filter (used to update the filter)
                    dfilt[curr_f] += dconv_prev[curr_f, out_y, out_x] * conv_in[:, curr_y:curr_y+f, curr_x:curr_x+f]
                    # loss gradient of the input to the convolution operation (conv1 in the case of this network)
                    dout[:, curr_y:curr_y+f, curr_x:curr_x+f] += dconv_prev[curr_f, out_y, out_x] * filt[curr_f]
                    curr_x += s
                    out_x += 1
                curr_y += s
                out_y += 1
            # loss gradient of the bias
            dbias[curr_f] = np.sum(dconv_prev[curr_f])

        return dout, dfilt, dbias

    def maxpoolBackward(self, dpool, orig, f, s):
        '''
        Backpropagation through a maxpooling layer. The gradients are passed through the indices of greatest value in the original maxpooling during the forward step.
        '''
        (n_c, orig_dim, _) = orig.shape

        dout = np.zeros(orig.shape)

        for curr_c in range(n_c):
            curr_y = out_y = 0
            while curr_y + f <= orig_dim:
                curr_x = out_x = 0
                while curr_x + f <= orig_dim:
                    # obtain index of largest value in input for current window
                    (a, b) = nanargmax(orig[curr_c, curr_y:curr_y+f, curr_x:curr_x+f])
                    dout[curr_c, curr_y+a, curr_x+b] = dpool[curr_c, out_y, out_x]

                    curr_x += s
                    out_x += 1
                curr_y += s
                out_y += 1

        return dout


    #####################################################
    ##################### Prediction ####################
    #####################################################

    def predict(self, image_list):
        '''
        Make predictions with trained filters/weights.
        '''
        conv_s, pool_f, pool_s = self.conv_stride, self.f_pool, self.pool_stride
        f1 = self.params.get('f1')
        f2 = self.params.get('f2')
        w3 = self.params.get('w3')
        w4 = self.params.get('w4')
        b1 = self.params.get('b1')
        b2 = self.params.get('b2')
        b3 = self.params.get('b3')
        b4 = self.params.get('b4')

        list_probs = []

        for i in trange(len(image_list)):
            image = image_list[i]
            conv1 = self.convolution(image, f1, b1, conv_s) # convolution operation
            conv1[conv1<=0] = 0 #relu activation
            pooled1 = self.maxpool(conv1, pool_f, pool_s) # maxpooling operation

            conv2 = self.convolution(pooled1, f2, b2, conv_s) # second convolution operation
            conv2[conv2<=0] = 0 # pass through ReLU non-linearity
            pooled = self.maxpool(conv2, pool_f, pool_s) # maxpooling operation
            (nf2, dim2, _) = pooled.shape

            fc = pooled.reshape((nf2 * dim2 * dim2, 1)) # flatten pooled layer

            z = w3.dot(fc) + b3 # first dense layer
            z[z<=0] = 0 # pass through ReLU non-linearity

            out = w4.dot(z) + b4 # second dense layer
            probs = softmax(out) # predict class probabilities with the softmax activation function
            list_probs.append(probs)

        return list_probs

#####################################################
################## Utility Methods ##################
#####################################################

def softmax(X):
    out = np.exp(X)
    return out/np.sum(out)

def categoricalCrossEntropy(probs, label):
    return -np.sum(label * np.log(probs))

def nanargmax(arr):
    idx = np.nanargmax(arr)
    idxs = np.unravel_index(idx, arr.shape)
    return idxs

def compute_accuracy_metrics(Y_test, P_pred, use_opt_threshold=False, verbose=True):

    # y_test = binary label
    # P_pred = predicted probability for y_test
    # compuate various binary classification accuracy metrics
    fpr, tpr, thresholds = metrics.roc_curve(Y_test, P_pred, pos_label=None)
    mythre = thresholds[np.argmax(tpr - fpr)]
    myauc = metrics.auc(fpr, tpr)
    # print('!!! auc', myauc)

    # Compute classification statistics
    threshold = 0.5
    if use_opt_threshold:
        threshold = mythre

    Y_pred = P_pred.copy()
    Y_pred[Y_pred < threshold] = 0
    Y_pred[Y_pred >= threshold] = 1

    mcm = confusion_matrix(Y_test, Y_pred)

    tn = mcm[0, 0]
    tp = mcm[1, 1]
    fn = mcm[1, 0]
    fp = mcm[0, 1]

    accuracy = (tp + tn) / (tp + tn + fp + fn)
    sensitivity = tn / (tn + fp)
    specificity = tp / (tp + fn)
    precision = tp / (tp + fp)
    fall_out = fp / (fp + tn)
    miss_rate = fn / (fn + tp)

    # Save results
    results_dict = {}
    results_dict.update({'Y_test': Y_test})
    results_dict.update({'Y_pred': Y_pred})
    results_dict.update({'AUC': myauc})
    results_dict.update({'Opt_threshold': mythre})
    results_dict.update({'Accuracy': accuracy})
    results_dict.update({'Sensitivity': sensitivity})
    results_dict.update({'Specificity': specificity})
    results_dict.update({'Precision': precision})
    results_dict.update({'Fall_out': fall_out})
    results_dict.update({'Miss_rate': miss_rate})
    results_dict.update({'Confusion_mx': mcm})


    if verbose:
        for key in [key for key in results_dict.keys()]:
            if key not in ['Y_test', 'Y_pred', 'Confusion_mx']:
                print('% s ===> %.3f' % (key, results_dict.get(key)))
        print('Confusion matrix  ===> \n', mcm)

    return results_dict


def multiclass_accuracy_metrics(Y_test, P_pred, class_labels=None, use_opt_threshold=False):
    # y_test = multiclass one-hot encoding  labels [samples x labels]
    # Q = predicted probability for y_test
    # compuate various classification accuracy metrics
    results_dict = {}
    y_test = []
    y_pred = []
    for i in np.arange(Y_test.shape[0]):
        for j in np.arange(Y_test.shape[1]):
            if Y_test[i,j] == 1:
                y_test.append(j)
            if P_pred[i,j] == np.max(P_pred[i,:]):
                # print('!!!', np.where(P_pred[i,:]==np.max(P_pred[i,:])))
                y_pred.append(j)

    confusion_mx = metrics.confusion_matrix(y_test, y_pred)
    results_dict.update({'confusion_mx':confusion_mx})
    results_dict.update({'Accuracy':np.trace(confusion_mx)/np.sum(np.sum(confusion_mx))})
    print('!!! confusion_mx', confusion_mx)
    print('!!! Accuracy', results_dict.get('Accuracy'))


    return results_dict

def list2onehot(y, list_classes):
    """
    y = list of class lables of length n
    output = n x k array, i th row = one-hot encoding of y[i] (e.g., [0,0,1,0,0])
    """
    Y = np.zeros(shape = [len(y), len(list_classes)], dtype=int)
    for i in np.arange(Y.shape[0]):
        for j in np.arange(len(list_classes)):
            if y[i] == list_classes[j]:
                Y[i,j] = 1
    return Y

def onehot2list(y, list_classes=None):
    """
    y = n x k array, i th row = one-hot encoding of y[i] (e.g., [0,0,1,0,0])
    output =  list of class lables of length n
    """
    if list_classes is None:
        list_classes = np.arange(y.shape[1])

    y_list = []
    for i in np.arange(y.shape[0]):
        idx = np.where(y[i,:]==1)
        idx = idx[0][0]
        y_list.append(list_classes[idx])
    return y_list
